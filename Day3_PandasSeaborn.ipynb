# %%
import pandas as pd

# %%
df=pd.read_csv("/content/mydf1.csv")
df
# Out:
#     Unnamed: 0   Names Initials      SEM1  SEM2       SEM3 Grade  Placed  \
# 0            0     Joe        K  9.800000  10.0   9.900000    A+       1
# 1            1  Rajesh        M  8.900000   9.1   9.300000     A       1
# 2            2  Kissan        V  9.900000   9.8  10.000000     A       0
# 3            3    Mary        N  7.700000   8.0   8.992857     B       0
# 4            4    Jeen        K  9.800000   9.1   9.900000    A+       1
# 5            5     Raj        M  8.900000   9.1   9.300000     A       1
# 6            6  Hassan        V  9.900000   9.0   9.200000     A       1
# 7            7    Mari        N  7.700000   8.0   7.100000     B       1
# 8            8    Jess        K  8.992857   9.1   9.900000    A+       1
# 9            9  Rajini        M  8.992857   9.1   9.300000     A       0
# 10          10   Kiran        V  8.992857   9.3   9.200000     A       0
# 11          11    Maya        N  7.700000   8.0   7.100000     B       0
# ...

# %%
import seaborn as sns
pl=sns.lineplot(y="Names",x="SEM1",data=df) #sns.lineplot(x,yu,data=dataframe name)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-67-3f4f628ece37> in <cell line: 2>()
#       1 import seaborn as sns
# ----> 2 pl=sns.lineplot(y="Names",x="SEM1",data=df) #sns.lineplot(x,yu,data=dataframe name)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     478     errorbar = _deprecate_ci(errorbar, ci)
#     479
# --> 480     p = _LinePlotter(
#     481         data=data,
#     482         variables=dict(
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in __init__(self, data, variables, estimator, n_boot, seed, errorbar, sort, orient, err_style, err_kws, legend)
# ...

# %%
sns.relplot(data=df,x="SEM1",y="Names",col="Placed")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-62-6274a0259fb8> in <cell line: 1>()
# ----> 1 sns.relplot(data=df,x="SEM1",y="Names",col="Placed")
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in relplot(data, x, y, hue, size, style, units, weights, row, col, col_wrap, row_order, col_order, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, dashes, style_order, legend, kind, height, aspect, facet_kws, **kwargs)
#     741             msg = "The `weights` parameter has no effect with kind='scatter'."
#     742             warnings.warn(msg, stacklevel=2)
# --> 743     p = Plotter(
#     744         data=data,
#     745         variables=variables,
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     389         )
#     390
# ...

# %%
df=pd.read_excel("/content/diabetes.xlsx")
df.tail()
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative

# %%
df=pd.read_excel("/content/diabetes.xlsx")
df['index']=range(0,768)
df
# Out:
#      preg  plas  pres  skin  insu  mass   pedi  age            class  index
# 0       6   148    72    35     0  33.6  0.627   50  tested_positive      0
# 1       1    85    66    29     0  26.6  0.351   31  tested_negative      1
# 2       8   183    64     0     0  23.3  0.672   32  tested_positive      2
# 3       1    89    66    23    94  28.1  0.167   21  tested_negative      3
# 4       0   137    40    35   168  43.1  2.288   33  tested_positive      4
# ..    ...   ...   ...   ...   ...   ...    ...  ...              ...    ...
# 763    10   101    76    48   180  32.9  0.171   63  tested_negative    763
# 764     2   122    70    27     0  36.8  0.340   27  tested_negative    764
# 765     5   121    72    23   112  26.2  0.245   30  tested_negative    765
# 766     1   126    60     0     0  30.1  0.349   47  tested_positive    766
# 767     1    93    70    31     0  30.4  0.315   23  tested_negative    767
#
# [768 rows x 10 columns]

# %%
sns.relplot(data=df,x="index",y="age",col='class',marker="*")

# %%
tips=sns.load_dataset("tips")
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=tips,x="total_bill",y="tip",hue="sex")

# %%
dj=sns.load_dataset("dowjones")
dj
# Out:
#           Date   Price
# 0   1914-12-01   55.00
# 1   1915-01-01   56.55
# 2   1915-02-01   56.00
# 3   1915-03-01   58.30
# 4   1915-04-01   66.45
# ..         ...     ...
# 644 1968-08-01  883.72
# 645 1968-09-01  922.80
# 646 1968-10-01  955.47
# 647 1968-11-01  964.12
# 648 1968-12-01  965.39
#
# [649 rows x 2 columns]

# %%
sns.relplot(data=dj,x="Date",y="Price",kind="line")

# %%
fm=sns.load_dataset("fmri")
fm
# Out:
#      subject  timepoint event    region    signal
# 0        s13         18  stim  parietal -0.017552
# 1         s5         14  stim  parietal -0.080883
# 2        s12         18  stim  parietal -0.081033
# 3        s11         18  stim  parietal -0.046134
# 4        s10         18  stim  parietal -0.037970
# ...      ...        ...   ...       ...       ...
# 1059      s0          8   cue   frontal  0.018165
# 1060     s13          7   cue   frontal -0.029130
# 1061     s12          7   cue   frontal -0.004939
# 1062     s11          7   cue   frontal -0.025367
# 1063      s0          0   cue  parietal -0.006899
#
# [1064 rows x 5 columns]

# %%
sns.relplot(data=fm,x="timepoint",y="signal")

# %%
sns.catplot(data=tips,x="total_bill",y='day')

# %%
sns.catplot(data=tips,y="total_bill",x='time',kind="violin",hue="smoker")

# %%
sns.catplot(data=tips,y="total_bill",x='time',kind="box",hue="smoker")
